# %%
# The Big Rosella Festival Programmed by : ICT242_Industry_Project_Group_B

# %%
page = """
<!DOCTYPE html>
<html>
<head>
  <meta name="viewport" content="width=device-width, initial-scale=1">
<link rel="stylesheet" href="style.css">
<link rel="stylesheet" href="chkout.css">
<link rel="stylesheet" href="contact.css">
<link rel="stylesheet" href="about.css">
<link rel="stylesheet" href="activities.css">
<link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
<script src="navbar.js"></script>
<script
    src="https://www.paypal.com/sdk/js?client-id=AU6Y-JLJTiIu5WMiclvuXMPlJkQHhNdwolssjBeBoXVCwh6AIjVI7RtkrDYsp-heA6ShEzSRzY45eh5Z
"> // Required. Replace SB_CLIENT_ID with your sandbox client ID.
  </script>

</head>

<body>
<div class="header">
  <img class="logo" src="ccs_logo.png" alt="Ccs Logo" usemap="#workmap"href="homepage.html">
  <map name="workmap">
  <area shape="default"alt="Whole Logo" href="homepage.html">
  </map>
</map>
  <h1>Big Rosella Festival</h1>
 
  </div>
  <div class="topnav" id="myTopnav">
  <a href="homepage.html" class="active">Home</a>
 <a href="activities.html">Activities</a>
  <a href="contact.html">Contact</a>
  <a href="bookticket.html">Book Ticket</a>
  <a href="about.html">About</a>
  <a href="javascript:void(0);" style="font-size:15px;" class="icon" onclick="myFunction()">&#9776;</a>
</div>

{heading}
{contents}
<div class="footer">
  <br><h2>Big Rosella Festival</h2></br>
<div class="row">
  <div class="side">
      <p>
        Follow our social media!
      </p>
      <p>
        <br><a href="https://www.facebook.com/ccskitchen/">Facebook</a></br>
        <br><a href="https://www.instagram.com/ccs.kitchen/">Instagram</a></br>
        <br><a href="https://www.facebook.com/petersensfarm/">Petersen's Farm</a></br>
      </p>
    </div>
    <div class="side">
      <p>
        Our Website
      </p>
      <br><a href="homepage.html">Home</a></br>
      <br><a href="activities.html">Activities</a></br>
      <br><a href="about.html">About</a></br>
      <br><a href="contact.html">Contact</a></br>
      <br><a href="checkout.html">Checkout</a></br>
    </div>
  </div>
</div>
</body>
</html>
"""

# %%
cont_main="""

<div  class="container">
<img src="Photos/frontimagehome.png" alt="Group picture with products"class="fakeimg">
 <div id="sticky_container">
 <p>Entry price: $10 per person</p>
    <button onclick="document.location = 'bookticket.html'">Book Now</button>
    </div>
  

 <div class="main">
 <p>
  <br>This year, CC is taking the Big Rosella Festival Online!</br>
  Due to COVID-19, this year we have had to improvise so this year the festival is going to be online!
  <br>CC's Kitchen and Petersens' Farm is proud to announce the first ever VIRTUAL BIG ROSELLA FESTIVAL on 2nd, 3rd and 4th of May zooming from our PETERSEN'S FARM to the comforts of your own home!</br>
  <br>Watch this space for announcements and the upcoming program and we look forward to bringing your all things Rosella!</br>
  Go to our <a href="https://www.facebook.com/bigrosellafestival/">Facebook page</a> and see our LIVE Streams and Demonstrations as they happen!
  </p>
  </div>
  
<img src="Photos/20180512_140132 - Copy.jpg" alt="Group picture with products" class="fakeimg">



<div class="row">
  <div class="side">
    <p>
      <br>Find more about the Big Rosella Festival and who we are by visiting our <a href="about.html">about page</a></br>

    </p>
  </div>

  <div class="side">
    <p>
      <br>The Big Rosella has a wide range of activities for everyone.</br>
      <br>More about these activities can be found <a href="activities.html">here</a></br>
    </p>
  </div>
  </div>

  <img src="Photos/High Res (77 of 153).jpg" alt="Crowd" class="fakeimg">
  <div class="main">
  <p>

    <br>Feel free to contact us or find information by visiting our <a href="contact.html">contact page</a></br>

  </p>
  </div>


</div>
"""

out = open("homepage.html", "w")
out.write(page.format(heading="",contents=(cont_main)))
out.close()

# %%
act_item1="""<style>
  h3{text-align: center;}
    p {
  text-align: center;
  font-size: 120%;
  font-family: arial;
  margin-right: 150px;
  margin-left: 150px;
  }

  img{
   width: 50%;
   height: 50%;
     }
   .center {
  display: block;
  margin-left: auto;
  margin-right: auto;
  width: 50%;
}
</style>
<h3>Farm Tours</h3>
<p>By attending a formal tour, you will be able to hear the stories behind the designs and construction taking place.
  Participants will hear about many elements currently in place and others in development from hot composting to organic food, paddock to plate
  restaurant and fermentation, animal integration, market gardens, KidFarmer,learning experiences through Giving Tree and lots more. </p>
<img src="Photos/High Res (10 of 153).jpg" alt="Greg talking about the Rosssella plant" class="center">
<h3>Cooking with the stars</h3>
<p>People who attend the fetival wil be treated to learn how to cook dishes with the Rosssella plant by first watching Glen Barratt and others, how they get the job done and then by applying what
  you've leanred!</p>
<img src="Photos/High Res (143 of 153).jpg" alt="Famous chef" class="center">
<h3>Face Paintings</h3>
<p>Kids which come to the festival will be treated to facepaintings of animals and plants which are grown on the farm. They will also have a chnace to learn more about the Rossella plant
  while they get their face painted!</p>
<img src="Photos/High Res (36 of 153).jpg" alt="Face painting" class="center">
<h3>Farmer Talks Q&A's</h3>
<p>Both kids and adults will have a chnace at asking question to all the farmers that came to finding out how to run a farm, how to grow the Rosella plant and what makes the plant
  unique.</p>
<img src="Photos/High Res (16 of 153).jpg" alt="Face painting" class="center">

"""
out = open("activities.html", "w")
out.write(page.format(heading="<h2>Activities</h2>",contents=(act_item1)))
out.close()

# %%
con_f1="""<style>

    p {
  text-align: centre;
  font-size: 120%;
  font-family: arial;


  }

</style>

<div class="container">
  <div style="text-align:center">
    <p>For more information, don't hesitate to contact us!</p>
  </div>
  <div class="row">
    <div class="column">
      <h3>Petersen's Farm</h3>
      <p>
        <br>Petersen's Farm: 2 Reilly Road, Woolooga</br>
        <br>Phone: 0411 624 648</br>
        <br>Email: ccs_kitchen@yahoo.com</br>
      </p>

    </div>
    <div class="column">

      <style>
      #map {
        width: 100%;
        height: 400px;
        background-color: grey;
      }
    </style>

      <!--The div element for the map -->
      <div id="map"></div>
      <script>
// Initialize and add the map
function initMap() {
  // The location of Uluru
  var bigrosella = {lat: -25.985759, lng: 152.403343};
  // The map, centered at Uluru
  var map = new google.maps.Map(
      document.getElementById('map'), {zoom: 10, center: bigrosella});
  // The marker, positioned at Uluru
  var marker = new google.maps.Marker({position: bigrosella, map: map});
}
    </script>
      <!--Load the API from the specified URL
      * The async attribute allows the browser to render the page while the API loads
      * The key parameter will contain your own API key (which is not needed for this tutorial)
      * The callback parameter executes the initMap() function
      -->
      <script async defer
              src="https://maps.googleapis.com/maps/api/js?key=AIzaSyCO3hE4bE7WV7mGuXL4kn9caoWI44tD8Ic&callback=initMap">
      </script>

    </div>
  </div>
</div>"""
out = open("contact.html", "w")
out.write(page.format(heading="<h2>Contact us</h2>",contents=(con_f1)))
out.close()

# %%
chk_form= """<form>

    <fieldset>
        <p>Each ticket costs $10 per person aged 16 or over. </p>
        <p>Free entry for children under 16 years old. </p>
        <table>
            <tr><td style="padding:0 5px 5px 0;">Price/ticket Aud</td><td style="padding:0 5px 5px 0;"><input type="text" name="TPRICE" id="TPRICE" value="10" readonly/></td></tr>
            <tr><td style="padding:0 5px 5px 0;">Quantity</td><td style="padding:0 5px 5px 0;"><input type="number" value="" name="QTY" id="QTY" min="0" max="100" step="1" onKeyUp="multiply()" /></td></tr>
            <tr><td style="padding:0 5px 5px 0;">Total Amount Aud</td><td style="padding:0 5px 5px 0;"><input type="text" name="amount" id="TOTAL" maxlength="200" /></td></tr>
            <tr><td style="padding:0 5px 5px 0;"><input type="hidden" name="on0" value="Reference" />Reference</td><td style="padding:0 5px 5px 0;"> <input type="text" name="os0" maxlength="200" /></td></tr>
            <tr><td>&nbsp;</td><td style="padding:0 5px 5px 0;">
        </table>
    </fieldset>
</form>
<p>Select an option to pay</p>
<div id="paypal-button-container"></div>

<script>
var c=0;
  function multiply() {
    a = Number(document.getElementById('QTY').value);
    b = Number(document.getElementById('TPRICE').value);
    c = a * b;
    document.getElementById('TOTAL').value = c;
  }

  paypal.Buttons({
      style: {
          shape: 'rect',
          color: 'gold',
          layout: 'vertical',
          label: 'paypal',

      },
      createOrder: function(data, actions) {
          return actions.order.create({
              purchase_units: [{
                  amount: {
                      value: c
                  }
              }]
          });
      },
      onApprove: function(data, actions) {
          return actions.order.capture().then(function(details) {
              alert('Transaction completed by ' + details.payer.name.given_name + '!');
          });
      }
  }).render('#paypal-button-container');
</script>"""
out = open("bookticket.html", "w")
out.write(page.format(heading="<h2>Book Ticket</h2>",contents=(chk_form)))
out.close()

# %%
abt_l1="""
<style>

   .left {
  display: block;
  margin-left: auto;
  margin-top: 35px;
  margin-right: auto;
  width: 90%;
  height: 90%;
  }

  p {
  text-align: left;
  font-size: 120%;
  font-family: arial;
  margin-right: 150px;
  margin-left: 150px;
  }

</style>

<h2>About us</h2>
<div class="container">
  <div class="row">
    <div class="column">
      <img src="Photos/IMG_6366 - Copy.jpg" alt="Famous chef" class="left">


    </div>
    <div class="column">
      <p>
        <br>By using what begins in the fertile ground of a small Woolooga property, 45km West of Gympie Cecilia "CC" Diaz-Petersen is adding to the foodie world with her mouth-watering range of fine foods.</br>

        <br>Born in the Philippines, CC's passion for food and cooking started at a young age with influences from her mother, grandmothers, uncles and aunties - all excellent home-grown cooks.</br>

        <br>In 1987, CC moved to Australia with her parents and 2 siblings. After almost a decade working as a Real Estate Sales Agent in Sydney and Wide Bay Region, CC decided to chase her dream and launched CC's Kitchen in early 2011.</br>

        <br>A taste of CC's products takes you back in time - a time before preservatives and artificial flavourings and colourings - when food went straight from the garden to the pot to the plate.</br>

        <br>A good dose of love, time and patience are the keys ingredients. All products are 100% made and produced right here at the Petersen's Farm at Woolooga, Queensland 40 kms West of Gympie grown by Greg Petersen, CC's husband and his parents. We utilise fresh produce such as gourmet tomatoes, green papaya, herbs, rosellas, gooseberries, chillies, beans, cauliflower, zucchinis, eggplant and wide variety of Asian veggies. All cooked and seasoned with homemade love!</br>

        <br>They are the stars of CC's ever growing product range - a seasonal affair where CC makes everything by hand in her kitchen and where chunks of real food and flavour leave supermarket pureed versions in the dust. It's like what grandma used to make - it's a premium product using the best of Gympie produce.</br>

        <br>CC's Kitchen products can be found in speciality shops and butcher shops, trade shows/festivals or at markets around the region from Maryborough, Hervey Bay, Tin Can Bay, Sunshine Coast and Brisbane area.</br>
      </p>


    </div>
  </div>
</div>

  """
out = open("about.html", "w")
out.write(page.format(heading="<h2>About us</h2>",contents=(abt_l1)))
out.close()
